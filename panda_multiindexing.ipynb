# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv("C:/Users/Thamizhiniyan/Desktop/pandasdataset/multi_index_warehouses.csv")

# %%
df.head()
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2     2010   2010.1     2011   2011.1     2012   2012.1     2013   2013.1     2014   2014.1     2015   2015.1     2016   2016.1     2017   2017.1     2018   2018.1     2019   2019.1
# 0            NaN        NaN        NaN  Jan-Jun  Jul-Dec  Jan-Jun  Jul-Dec  Jan-Jun  Jul-Dec  Jan-Jun  Jul-Dec  Jan-Jun  Jul-Dec  Jan-Jun  Jul-Dec  Jan-Jun  Jul-Dec  Jan-Jun  Jul-Dec  Jan-Jun  Jul-Dec  Jan-Jun  Jul-Dec
# 1            NaN        NaN        NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2  NY Warehouses    Buffalo     Mobile       26       12       10       23       18       10       10       26       16       18       20       21       20       26       29       20       11       21       25       16
# ...

# %%
# my header is inappropriate and it lies at index 0,1 
# my index is column 0,1,2
# so lets makes the changes accordingly

# %%
# lets once again call load the dataset with changes

# %%
df = pd.read_csv("C:/Users/Thamizhiniyan/Desktop/pandasdataset/multi_index_warehouses.csv",index_col= [0,1,2],header=[0,1])

# %%
df
# Out:
#                                       2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
#                                    Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# NY Warehouses Buffalo       Mobile      26      12      10      23      18      10      10      26      16      18      20      21      20      26      29      20      11      21      25      16
#                             TV          19      22      27      19      27      12      24      28      27      28      10      16      25      26      20      25      10      27      20      20
#                             AC          16      24      20      23      29      15      10      20      16      16      25      21      19      12      21      19      11      28      19      19
# ...

# %%
df.shape
# Out:
# (27, 20)

# %%
# lets sort the df according to index
df.sort_index(inplace =True)

# %%
df.head()
# Out:
#                                     2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
#                                  Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# CA Warehouses Los Angeles AC          27      24      20      21      20      29      18      29      15      17      27      25      12      23      23      14      29      25      25      16
#                           Mobile      29      15      14      28      29      27      18      27      16      29      10      15      20      17      11      14      25      11      29      19
#                           TV          23      14      18      21      10      15      11      19      25      11      12      11      23      20      22      21      21      17      15      10
# ...

# %%
# printing the index names of the columns
print("level0:",df.index.levels[0])
print("level1:",df.index.levels[1])
print("level2:",df.index.levels[2])
# Out:
# level0: Index(['CA Warehouses', 'NY Warehouses', 'TX Warehouses'], dtype='object')
# level1: Index(['Arlington', 'Austin', 'Beacon', 'Buffalo', 'Houston', 'Ithaca', 'Los Angeles', 'San Diego', 'San Francisco'], dtype='object')
# level2: Index(['AC', 'Mobile', 'TV'], dtype='object')

# %%
# lets look at index names
df.index.names  ## --> it is frozen list
# Out:
# FrozenList([None, None, None])

# %%
#lets name the index 
df.index.names = ["State", "City", "Products"]

# %%
df.index.names
# Out:
# FrozenList(['State', 'City', 'Products'])

# %%
#lets name the columns,
df.columns.names
# Out:
# FrozenList([None, None])

# %%
df.columns.names =["Year","Sem"]

# %%
df.columns.names
# Out:
# FrozenList(['Year', 'Sem'])

# %%
# indexing concepts in multi-indexing :
df.loc[('NY Warehouses'):,:] ## --> indexing all the rows from NY warehouses till end and all the rows
# Out:
# Year                                2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                              Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City      Products
# NY Warehouses Beacon    AC            13      11      23      13      20      26      10      12      14      10      28      26      21      26      29      12      29      18      20      24
#                         Mobile        10      17      24      27      25      11      22      26      10      13      25      13      29      23      28      22      22      26      20      18
# ...

# %%
# let me trry to get the any value using thee index and column name by indexing
#df.loc[(row),(columns)]

# %%
df.loc[("NY Warehouses","Buffalo","Mobile"),(2010,"Jan-Jun")] 
# it gives 26 ,but we get the Key Error #KeyError: (2010, 'Jan-Jun')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2010
#
# ...

# %%
# we need need to chage the datatype of the columns 
df.columns.levels
# Out:
# FrozenList([['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019'], ['Jan-Jun', 'Jul-Dec']])

# %%
change_col_dtype = df.columns.levels[0].astype(int)
df.columns.set_levels(levels = change_col_dtype,level =0,inplace =True)
# Out:
# C:\Users\Thamizhiniyan\AppData\Local\Temp\ipykernel_3644\4191818381.py:2: FutureWarning: inplace is deprecated and will be removed in a future version.
#   df.columns.set_levels(levels = change_col_dtype,level =0,inplace =True)

# %%
df.loc[("NY Warehouses","Buffalo","Mobile"),(2010,"Jan-Jun")]
# Out:
# 26

# %%
df.columns.levels
# Out:
# FrozenList([[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], ['Jan-Jun', 'Jul-Dec']])

# %%
# lets perform spliting with the multi indexing concepts
# rows ,columns
# ():(),():()

# %%
df.loc[("NY Warehouses"):("TX Warehouses"),(2010):(2011)]
# Out:
# Year                                2010            2011
# Sem                              Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City      Products
# NY Warehouses Beacon    AC            13      11      23      13
#                         Mobile        10      17      24      27
#                         TV            12      22      26      26
#               Buffalo   AC            16      24      20      23
#                         Mobile        26      12      10      23
#                         TV            19      22      27      19
#               Ithaca    AC            18      17      19      28
#                         Mobile        10      28      27      22
#                         TV            13      13      11      15
# TX Warehouses Arlington AC            21      18      13      22
#                         Mobile        29      10      12      13
#                         TV            15      20      22      25
# ...

# %%
#lets get only NY

# %%
df.loc[("NY Warehouses"),:]
# or
df.loc[("NY Warehouses")]
# Out:
# Year                2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem              Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# City    Products
# Beacon  AC            13      11      23      13      20      26      10      12      14      10      28      26      21      26      29      12      29      18      20      24
#         Mobile        10      17      24      27      25      11      22      26      10      13      25      13      29      23      28      22      22      26      20      18
#         TV            12      22      26      26      15      28      15      26      12      18      17      10      21      19      24      23      26      19      19      13
# ...

# %%
df.loc[("NY Warehouses","Buffalo","Mobile"):("TX Warehouses","Arlington","Tv"),(2010,"Jul-Dec"):(2011,"Jan-Jun")]
# Out:
# Year                                2010    2011
# Sem                              Jul-Dec Jan-Jun
# State         City      Products
# NY Warehouses Buffalo   Mobile        12      10
#                         TV            22      27
#               Ithaca    AC            17      19
#                         Mobile        28      27
#                         TV            13      11
# TX Warehouses Arlington AC            18      13
#                         Mobile        10      12
#                         TV            20      22

# %% [markdown]
# ## Xs cross section

# %%
df.xs(("AC"),level=("Products"))
# Out:
# Year                           2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                         Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City
# CA Warehouses Los Angeles        27      24      20      21      20      29      18      29      15      17      27      25      12      23      23      14      29      25      25      16
#               San Diego          11      22      10      29      24      24      24      11      18      27      29      10      16      28      12      19      10      15      20      15
#               San Francisco      10      14      10      16      17      20      28      25      27      11      19      18      22      13      16      13      21      16      15      23
# ...

# %%
df.xs(("AC"),level=("Products"),drop_level = False)
# Out:
# Year                                    2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                                  Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City          Products
# CA Warehouses Los Angeles   AC            27      24      20      21      20      29      18      29      15      17      27      25      12      23      23      14      29      25      25      16
#               San Diego     AC            11      22      10      29      24      24      24      11      18      27      29      10      16      28      12      19      10      15      20      15
# ...

# %%
df.xs(("NY Warehouses","AC"),level=("State","Products"),drop_level = False)
# Out:
# Year                              2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                            Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City    Products
# NY Warehouses Beacon  AC            13      11      23      13      20      26      10      12      14      10      28      26      21      26      29      12      29      18      20      24
#               Buffalo AC            16      24      20      23      29      15      10      20      16      16      25      21      19      12      21      19      11      28      19      19
#               Ithaca  AC            18      17      19      28      28      14      21      18      25      17      18      27      23      24      22      12      11      12      19      22

# %%
df.xs(("Jan-Jun"),level=("Sem"),axis=1,drop_level =False)
# Out:
# Year                                    2010    2011    2012    2013    2014    2015    2016    2017    2018    2019
# Sem                                  Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun
# State         City          Products
# CA Warehouses Los Angeles   AC            27      20      20      18      15      27      12      23      29      25
#                             Mobile        29      14      29      18      16      10      20      11      25      29
#                             TV            23      18      10      11      25      12      23      22      21      15
#               San Diego     AC            11      10      24      24      18      29      16      12      10      20
#                             Mobile        14      24      23      11      29      18      15      24      15      12
#                             TV            19      17      11      22      18      22      13      18      10      22
# ...

# %% [markdown]
# # take()

# %%
df.take([0,3,6]) # simply taking the AC of the CA without using XS
# Out:
# Year                                    2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                                  Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City          Products
# CA Warehouses Los Angeles   AC            27      24      20      21      20      29      18      29      15      17      27      25      12      23      23      14      29      25      25      16
#               San Diego     AC            11      22      10      29      24      24      24      11      18      27      29      10      16      28      12      19      10      15      20      15
# ...

# %%
df.xs(("CA Warehouses","AC"),level =("State","Products"),axis=0,drop_level =False) # same as the above
# Out:
# Year                                    2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                                  Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City          Products
# CA Warehouses Los Angeles   AC            27      24      20      21      20      29      18      29      15      17      27      25      12      23      23      14      29      25      25      16
#               San Diego     AC            11      22      10      29      24      24      24      11      18      27      29      10      16      28      12      19      10      15      20      15
# ...

# %% [markdown]
# # Slice()

# %%
# slice(stop)
# slice(start,stop,step)
# df.loc[(rows),(columns)]
# (rows) ---> (slice(level =0),slice(level =1),slice(level =2),......) #how rows defined ((),(),(),....) 
# (columns) ----> (slice(level =0),slice(level =1),.......) # how columns defined

# %%
df.loc[(slice("None"),slice("Beacon","Ithach"),"AC"),(slice(2010,2015),slice("Jan-Jun"))]
# Out:
# Year                              2010    2011    2012    2013    2014    2015
# Sem                            Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun
# State         City    Products
# NY Warehouses Beacon  AC            13      23      20      10      14      28
#               Buffalo AC            16      20      29      10      16      25
#               Ithaca  AC            18      19      28      21      25      18

# %%
df
# Out:
# Year                                    2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                                  Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City          Products
# CA Warehouses Los Angeles   AC            27      24      20      21      20      29      18      29      15      17      27      25      12      23      23      14      29      25      25      16
#                             Mobile        29      15      14      28      29      27      18      27      16      29      10      15      20      17      11      14      25      11      29      19
# ...

# %%
df.loc[(slice(None),slice(None),["TV","AC","Mobile"]),(slice(2019),slice('Jan-Jun'))]
# Out:
# Year                                    2010    2011    2012    2013    2014    2015    2016    2017    2018    2019
# Sem                                  Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun
# State         City          Products
# CA Warehouses Los Angeles   TV            23      18      10      11      25      12      23      22      21      15
#               San Diego     TV            19      17      11      22      18      22      13      18      10      22
#               San Francisco TV            28      15      28      27      12      13      18      17      10      19
# NY Warehouses Beacon        TV            12      26      15      15      12      17      21      24      26      19
#               Buffalo       TV            19      27      27      24      27      10      25      20      10      20
#               Ithaca        TV            13      11      12      27      10      20      17      13      15      15
# ...

# %%
df.loc[(["CA Warehouses","NY Warehouses"],slice(None),["Mobile","AC","TV"]),(slice(2019),slice("Jan-Jun"))]
# Out:
# Year                                    2010    2011    2012    2013    2014    2015    2016    2017    2018    2019
# Sem                                  Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun Jan-Jun
# State         City          Products
# CA Warehouses Los Angeles   Mobile        29      14      29      18      16      10      20      11      25      29
#               San Diego     Mobile        14      24      23      11      29      18      15      24      15      12
#               San Francisco Mobile        15      18      13      19      21      11      27      16      29      25
#               Los Angeles   AC            27      20      20      18      15      27      12      23      29      25
#               San Diego     AC            11      10      24      24      18      29      16      12      10      20
#               San Francisco AC            10      10      17      28      27      19      22      16      21      15
# ...

# %%
df
# Out:
# Year                                    2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                                  Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City          Products
# CA Warehouses Los Angeles   AC            27      24      20      21      20      29      18      29      15      17      27      25      12      23      23      14      29      25      25      16
#                             Mobile        29      15      14      28      29      27      18      27      16      29      10      15      20      17      11      14      25      11      29      19
# ...

# %% [markdown]
# # detail from San Fransisco

# %%
san_franc_sale = df.xs(("San Francisco"),level =("City"),axis =0,drop_level =False)

# %%
san_franc_sale
# Out:
# Year                                    2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                                  Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City          Products
# CA Warehouses San Francisco AC            10      14      10      16      17      20      28      25      27      11      19      18      22      13      16      13      21      16      15      23
#                             Mobile        15      25      18      16      13      13      19      15      21      23      11      26      27      16      16      18      29      22      25      20
# ...

# %%
print("total sale of all products over a decade:",san_franc_sale.sum().sum())
# Out:
# total sale of all products over a decade: 1140

# %%
print("Total sale of Tv alone:",san_franc_sale.xs(("TV"),level=("Products")).sum().sum())
# Out:
# Total sale of Tv alone: 398

# %%
print("Total sale of AC alone:",san_franc_sale.xs(("AC"),level=("Products")).sum().sum())
# Out:
# Total sale of AC alone: 354

# %%
print("Total sale of Mobile alone:",san_franc_sale.xs(("Mobile"),level=("Products")).sum().sum())
# Out:
# Total sale of Mobile alone: 388

# %%
398+354+388
# Out:
# 1140

# %% [markdown]
# ## 1st quater of all years

# %%
Q1_SF_sale = san_franc_sale.loc[(slice(None),slice(None),slice(None)),(slice(None),slice("Jan-Jun"))]

# %%
print("AC sale in 1stQ",Q1_SF_sale.xs(("AC"),level=("Products")).sum().sum())
print("TV sale in 1stQ",Q1_SF_sale.xs(("TV"),level=("Products")).sum().sum())
print("Mobile sale in 1stQ",Q1_SF_sale.xs(("Mobile"),level=("Products")).sum().sum())
# Out:
# AC sale in 1stQ 185
# TV sale in 1stQ 187
# Mobile sale in 1stQ 194

# %%
#san_franc_sale.loc[(()),(slice(None),slice("Jan-Jun"))]

# %%
#df.loc[(slice("TX Warehouse"),slice("San Francisco","Arlington"),["TV","Mobile"]),:]

# %% [markdown]
# # spliting from NY warehouse mobile of buffalo to TX warehouse Arlington`

# %%
df.loc[("NY Warehouses","Buffalo","Mobile"):("TX Warehouses","Arlington","Tv"),(2010,"Jul-Dec"):(2011,"Jan-Jun")]
# Out:
# Year                                2010    2011
# Sem                              Jul-Dec Jan-Jun
# State         City      Products
# NY Warehouses Buffalo   Mobile        12      10
#                         TV            22      27
#               Ithaca    AC            17      19
#                         Mobile        28      27
#                         TV            13      11
# TX Warehouses Arlington AC            18      13
#                         Mobile        10      12
#                         TV            20      22

# %%
df
# Out:
# Year                                    2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                                  Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City          Products
# CA Warehouses Los Angeles   AC            27      24      20      21      20      29      18      29      15      17      27      25      12      23      23      14      29      25      25      16
#                             Mobile        29      15      14      28      29      27      18      27      16      29      10      15      20      17      11      14      25      11      29      19
# ...

# %%
df.loc[("CA Warehouses","San Francisco","TV"):("TX Warehouses","Arlington","Mobile"),:]
# Out:
# Year                                    2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                                  Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City          Products
# CA Warehouses San Francisco TV            28      16      15      29      28      27      27      14      12      20      13      27      18      11      17      24      10      29      19      14
# NY Warehouses Beacon        AC            13      11      23      13      20      26      10      12      14      10      28      26      21      26      29      12      29      18      20      24
# ...

# %% [markdown]
# # NY sale_report of 10years

# %%
NY_total_sale_10y_report = df.xs(("NY Warehouses"),level=("State"),drop_level=False)

# %%
NY_total_sale_10y_report
# Out:
# Year                              2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                            Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City    Products
# NY Warehouses Beacon  AC            13      11      23      13      20      26      10      12      14      10      28      26      21      26      29      12      29      18      20      24
#                       Mobile        10      17      24      27      25      11      22      26      10      13      25      13      29      23      28      22      22      26      20      18
#                       TV            12      22      26      26      15      28      15      26      12      18      17      10      21      19      24      23      26      19      19      13
# ...

# %% [markdown]
# ## 2015 sale report of Buffalo city,from jan to jun

# %%
NY_total_sale_10y_report.loc[(slice(None),["Buffalo"],slice(None)),([2015],slice("Jan-Jun"))]
# Out:
# Year                              2015
# Sem                            Jan-Jun
# State         City    Products
# NY Warehouses Buffalo AC            25
#                       Mobile        20
#                       TV            10

# %%
NY_total_sale_10y_report.loc[("NY Warehouses","Buffalo","TV"),(2015,"Jan-Jun")]
# Out:
# 10

# %%
df.index.values
# Out:
# array([('CA Warehouses', 'Los Angeles', 'AC'),
#        ('CA Warehouses', 'Los Angeles', 'Mobile'),
#        ('CA Warehouses', 'Los Angeles', 'TV'),
#        ('CA Warehouses', 'San Diego', 'AC'),
#        ('CA Warehouses', 'San Diego', 'Mobile'),
#        ('CA Warehouses', 'San Diego', 'TV'),
#        ('CA Warehouses', 'San Francisco', 'AC'),
#        ('CA Warehouses', 'San Francisco', 'Mobile'),
#        ('CA Warehouses', 'San Francisco', 'TV'),
#        ('NY Warehouses', 'Beacon', 'AC'),
#        ('NY Warehouses', 'Beacon', 'Mobile'),
#        ('NY Warehouses', 'Beacon', 'TV'),
#        ('NY Warehouses', 'Buffalo', 'AC'),
#        ('NY Warehouses', 'Buffalo', 'Mobile'),
#        ('NY Warehouses', 'Buffalo', 'TV'),
#        ('NY Warehouses', 'Ithaca', 'AC'),
#        ('NY Warehouses', 'Ithaca', 'Mobile'),
#        ('NY Warehouses', 'Ithaca', 'TV'),
#        ('TX Warehouses', 'Arlington', 'AC'),
#        ('TX Warehouses', 'Arlington', 'Mobile'),
# ...

# %% [markdown]
# # TV sale of 10 years in all warehouses

# %%
tv_sales = df.xs(("TV"),level=("Products"),drop_level =False)

# %%
tv_sales
# Out:
# Year                                    2010            2011            2012            2013            2014            2015            2016            2017            2018            2019
# Sem                                  Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec Jan-Jun Jul-Dec
# State         City          Products
# CA Warehouses Los Angeles   TV            23      14      18      21      10      15      11      19      25      11      12      11      23      20      22      21      21      17      15      10
#               San Diego     TV            19      24      17      17      11      12      22      21      18      29      22      19      13      28      18      29      10      19      22      17
# ...

# %% [markdown]
# ### In 2017 jan-jun , CA and TX

# %%
tv_sales.loc[("CA Warehouses"),(2017,"Jan-Jun")].sum()
# Out:
# 57

# %%
tv_sales.loc[("TX Warehouses"),(2017,"Jan-Jun")].sum()
# Out:
# 60

# %% [markdown]
# # all products of CA warehouse sale for 10 years, 1st Quater

# %%
df.loc[(slice("CA Warehouses","CA Warehouses"),slice(None),slice(None)),(slice(None),slice('Jan-Jun'))].sum()
# Out:
# Year  Sem
# 2010  Jan-Jun    176
# 2011  Jan-Jun    146
# 2012  Jan-Jun    175
# 2013  Jan-Jun    178
# 2014  Jan-Jun    181
# 2015  Jan-Jun    161
# 2016  Jan-Jun    166
# 2017  Jan-Jun    159
# 2018  Jan-Jun    170
# 2019  Jan-Jun    182
# dtype: int64

# %% [markdown]
# # all products of NY warehouse sale for 10 years, 1st Quater

# %%
df.loc[(slice("NY Warehouses","NY Warehouses"),slice(None),slice(None)),(slice(None),slice('Jan-Jun'))].sum()
# Out:
# Year  Sem
# 2010  Jan-Jun    137
# 2011  Jan-Jun    187
# 2012  Jan-Jun    192
# 2013  Jan-Jun    161
# 2014  Jan-Jun    144
# 2015  Jan-Jun    184
# 2016  Jan-Jun    202
# 2017  Jan-Jun    201
# 2018  Jan-Jun    156
# 2019  Jan-Jun    186
# dtype: int64

# %% [markdown]
# # all products of TX warehouse sale for 10 years, 1stQuater

# %%
df.loc[(slice("TX Warehouses","TX Warehouses"),slice(None),slice(None)),(slice(None),slice('Jan-Jun'))].sum()
# Out:
# Year  Sem
# 2010  Jan-Jun    174
# 2011  Jan-Jun    174
# 2012  Jan-Jun    179
# 2013  Jan-Jun    169
# 2014  Jan-Jun    183
# 2015  Jan-Jun    186
# 2016  Jan-Jun    165
# 2017  Jan-Jun    186
# 2018  Jan-Jun    184
# 2019  Jan-Jun    182
# dtype: int64

# %% [markdown]
# # CA_TX watehouse combined sales report

# %%
df_CA_TX = df.drop("NY Warehouses")

# %%
print("total_item_sold_ca_tx_combined",df_CA_TX.sum().sum())
# Out:
# total_item_sold_ca_tx_combined 6971

# %% [markdown]
# # Q2 sale report of all warehouses in 2010

# %%
Q2_WH_report = df.drop(columns = ("Jan-Jun"),level = 1,axis=1)

# %%
Q2_WH_report.loc[:,2010]
# Out:
# Sem                                   Jul-Dec
# State         City          Products
# CA Warehouses Los Angeles   AC             24
#                             Mobile         15
#                             TV             14
#               San Diego     AC             22
#                             Mobile         27
#                             TV             24
#               San Francisco AC             14
#                             Mobile         25
#                             TV             16
# NY Warehouses Beacon        AC             11
#                             Mobile         17
#                             TV             22
#               Buffalo       AC             24
#                             Mobile         12
#                             TV             22
#               Ithaca        AC             17
#                             Mobile         28
#                             TV             13
# TX Warehouses Arlington     AC             18
# ...
